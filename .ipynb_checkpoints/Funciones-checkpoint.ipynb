# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
url = 'https://www.worldometers.info/coronavirus/'

# %%
# %%time
def makesoup(url):
    ''' connect and get the soup from the page'''
    response = requests.get(url)
    soup= BeautifulSoup(response.content, "html.parser")
    return soup#.find_all('td')
soup = makesoup(url)

world_pop = makesoup('https://www.worldometers.info/world-population/#:~:text=7.8%20Billion%20(2021),currently%20living)%20of%20the%20world.')
# Out:
# Wall time: 3.36 s

# %%
def get_data(soup):
    return soup.find_all('td')

# %%
def get_country_names(soup):
    '''get all the names of the listed countries'''
    return [i.string for i in soup.find_all( style="font-weight: bold; font-size:15px; text-align:left;" )]

# %% [markdown]
# # get the indices of each nation in the list

# %%
def get_country_indexes(countrylist):
    '''get the indexes where the countries are cited in the soup.
    This is done because we have no better insight of where to look at.
    So we use theese indexes and then parse their data in the next function'''
    indexes = {}
    for i in countrylist:
        indexes[i] = 'Notfound'

    countries_data = get_data(soup) 

    for i in countrylist:
        j=0
        while indexes[i] != 'NotFound' and j <= len(countries_data):
            if countries_data[j].string == i:
                indexes[i] = j
                break
            else:
                j+=1
    return indexes

# %%
# %%time
def get_world_index():
    j=0
    x=get_data(soup)
    while x[j].string != 'World':
        j+=1
    else:
        return j

world_index = get_world_index()
# Out:
# Wall time: 54.9 ms

# %%
def get_pops(soup):
    pops = {}
    for i in get_data(soup):
        j = i.find('a', class_= '')
        if j != None:
            countryname = re.findall('population/(.+)-population/',str(j))
            #print(countryname[0],j.string)
            #number = int(str(j.string).replace(',',''))
            pops[countryname[0]] = j.string
    if 'us' in pops.keys(): 
        pops['usa'] = pops['us']
    return pops

# %%
def get_one_country_index(soup, country):
    j=0
    x=get_data(soup) #depreciated
    #x=soup
    while x[j].string != str(country):
        j+=1
    else:
        index = j
    
    
    return index

# %%
def get_country_data(soup , index):
    x=soup 
    x=get_data(soup) #depreciated
    data = x[index:index+15]
    
    
    data = [i.string for i in data] #.lstrip('+') #put every number as a string
    
    if data[0].lower() in get_pops(soup).keys():
        data[-2] =pops[data[0].string.lower()] #put the info about the total  population

    
#     newdata=[]
#     for i in data[1:-1]:
#         if  i != None and i != 'N/A':
#             number=''
#             for j in i:
#                 if j in '0123456789':
#                     number+=j
#             newdata.append(number)
#         else:
#             newdata.append('NA')
#     data[1:-1] = newdata
    data[1:-1] = ['NA' if i == None or i ==  'N/A' or i.strip() == '' else i for i in data[1:-1]]
    data[1:-1] = [float(i.replace(',','')) if i != 'NA' else i for i in data[1:-1]] #I don't merge these two just in case some strange data appears
    
    #data[1:-1] = [ int(float(i.replace(',',''))) if i != None and i != 'N/A' and i!= ''  else 'NA' for i in data[1:-1]] # put every number as an int, and replace the missing vals with na



    return data

# %% [markdown]
# # make the df

# %%
get_one_country_index
# Out:
# <function __main__.get_one_country_index(soup, country)>

# %%
def df_top_countries(n):
    '''get the top n countries in terms of total cases'''
    
    cols = ['Country','Total Cases','New Cases','Total Deaths','New Deaths',
    'Total Recovered','New Recovered','Active Cases','Serious/Critical','TotalCases/1Mpop',
    'Deaths/1Mpop','Total Tests','Tests/1Mpop','Total pop','Region']
    
    stats = pd.DataFrame(get_country_data(soup,world_index), columns=['World'])
    
    for i in countries[0:n]:
    #print(get_country_data(soup,indexes[i]))
        stats[i] = get_country_data(soup,indexes[i])
    
    stats = stats.transpose()
    stats.columns = cols
    stats.set_index('Country',inplace=True)
    
    
    for i in stats.columns[0:-1]:
        stats[i] = stats[i].apply(lambda x : '{:,}'.format(float(x)) if x != 'NA' else x)
    
    return stats

# %%
def styler(df):
    
    return df.style\
.applymap(lambda x: 'background-color: indianred' if x =='NA' else  'background-color: snow', \
                                        subset = df.columns[0:-1])\
.applymap(lambda x : 'background-color: palegreen'if x != 'NA' else 'background-color: maroon' , subset = df.columns[0])\
.applymap(lambda x : 'background-color: lightgreen' if x == 'Asia' else
          'background-color: skyblue' if x == 'North America' or x== 'South America'  else
          'background-color: mediumslateblue' if x == 'Europe' else
          'background-color: pink' if x == 'Africa' else x
          , subset = df.columns[-1])

# %%
# %%time
soup = makesoup(url)
data = get_data(soup)
countries = get_country_names(soup)
indexes = get_country_indexes(countries)
#get_one_country_index(soup, country) to get one index only
world_index = get_world_index()
pops = get_pops(soup)
#get_country_data(soup,index_específico) to put this into df maker
df = df_top_countries(10) #gets the country data
styler(df)
# Out:
# Wall time: 5.45 s
# <style  type="text/css" >
# #T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row8_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row9_col0,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row10_col0{
#             background-color:  snow;
#             background-color:  palegreen;
#         }#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col2,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col4,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col6,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col7,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col8,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col9,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col10,#T_ ...
#             background-color:  snow;
#         }#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col10,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col11,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row0_col12,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col1,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col3,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col5,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col5{
#             background-color:  indianred;
#         }#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row1_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row3_col13{
#             background-color:  skyblue;
#         }#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row2_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row9_col13{
#             background-color:  lightgreen;
#         }#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row4_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row5_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row6_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row7_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row8_col13,#T_f76f9382_7df2_11eb_9fef_74d02b7b6285row10_col13{
#             background-color:  mediumslateblue;
#         }</style><table id="T_f76f9382_7df2_11eb_9fef_74d02b7b6285" ><thead>

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.6-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Collecting jdcal
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Building wheels for collected packages: et-xmlfile
#   Building wheel for et-xmlfile (setup.py): started
#   Building wheel for et-xmlfile (setup.py): finished with status 'done'
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8919 sha256=c0685367e6f36f570ee6144661fcc6d35abac12e2e6b962acdec89a5a1829c05
#   Stored in directory: c:\users\windows10\appdata\local\pip\cache\wheels\e2\bd\55\048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-3.0.6

# %%
from openpyxl import Workbook

# %%
df.to_excel('covid.xlsx',sheet_name="Sheet1")

# %%
indexes = get_country_indexes(get_country_names(soup))

# %%
indexes
# Out:
# {'USA': 153,
#  'India': 172,
#  'Brazil': 191,
#  'Russia': 210,
#  'UK': 229,
#  'France': 248,
#  'Spain': 267,
#  'Italy': 286,
#  'Turkey': 305,
#  'Germany': 324,
#  'Colombia': 343,
#  'Argentina': 362,
#  'Mexico': 381,
#  'Poland': 400,
#  'Iran': 419,
#  'South Africa': 438,
#  'Ukraine': 457,
#  'Indonesia': 476,
#  'Peru': 495,
#  'Czechia': 514,
#  'Netherlands': 533,
#  'Canada': 552,
#  'Chile': 571,
#  'Romania': 590,
#  'Portugal': 609,
#  'Israel': 628,
#  'Belgium': 647,
#  'Iraq': 666,
#  'Sweden': 685,
#  'Philippines': 704,
#  'Pakistan': 723,
#  'Switzerland': 742,
#  'Bangladesh': 761,
#  'Serbia': 780,
#  'Morocco': 799,
#  'Austria': 818,
#  'Hungary': 837,
#  'Japan': 856,
#  'Jordan': 875,
#  'UAE': 894,
#  'Lebanon': 913,
#  'Saudi Arabia': 932,
#  'Panama': 951,
#  'Slovakia': 970,
#  'Malaysia': 989,
#  'Belarus': 1008,
#  'Ecuador': 1027,
#  'Nepal': 1046,
#  'Georgia': 1065,
#  'Bulgaria': 1084,
#  'Bolivia': 1103,
#  'Croatia': 1122,
#  'Dominican Republic': 1141,
#  'Tunisia': 1160,
#  'Azerbaijan': 1179,
#  'Ireland': 1198,
#  'Kazakhstan': 1217,
#  'Denmark': 1236,
#  'Costa Rica': 1255,
#  'Greece': 1274,
#  'Lithuania': 1293,
#  'Kuwait': 1312,
#  'Palestine': 1331,
#  'Slovenia': 1350,
#  'Moldova': 1369,
#  'Egypt': 1388,
#  'Guatemala': 1407,
#  'Armenia': 1426,
#  'Honduras': 1445,
#  'Paraguay': 1464,
#  'Qatar': 1483,
#  'Ethiopia': 1502,
#  'Nigeria': 1521,
#  'Oman': 1540,
#  'Venezuela': 1559,
#  'Myanmar': 1578,
#  'Libya': 1597,
#  'Bosnia and Herzegovina': 1616,
#  'Bahrain': 1635,
#  'Algeria': 1654,
#  'Albania': 1673,
#  'Kenya': 1692,
#  'North Macedonia': 1711,
#  'S. Korea': 1730,
#  'Latvia': 1749,
#  'Kyrgyzstan': 1768,
#  'Ghana': 1787,
#  'Sri Lanka': 1806,
#  'Zambia': 1825,
#  'Uzbekistan': 1844,
#  'Montenegro': 1863,
#  'Estonia': 1882,
#  'Norway': 1901,
#  'Uruguay': 1920,
#  'Finland': 1939,
#  'Mozambique': 1958,
#  'El Salvador': 1977,
#  'Singapore': 1996,
#  'Luxembourg': 2015,
#  'Cuba': 2034,
#  'Afghanistan': 2053,
#  'Uganda': 2072,
#  'Namibia': 2091,
#  'Cyprus': 2110,
#  'Zimbabwe': 2129,
#  'Senegal': 2148,
#  'Cameroon': 2167,
#  'Ivory Coast': 2186,
#  'Malawi': 2205,
#  'Botswana': 2224,
#  'Australia': 2243,
#  'Sudan': 2262,
#  'Jamaica': 2281,
#  'DRC': 2300,
#  'Thailand': 2319,
#  'Malta': 2338,
#  'Angola': 2357,
#  'Maldives': 2376,
#  'Madagascar': 2395,
#  'Rwanda': 2414,
#  'French Polynesia': 2433,
#  'Mayotte': 2452,
#  'Mauritania': 2471,
#  'Eswatini': 2490,
#  'French Guiana': 2509,
#  'Guinea': 2528,
#  'Gabon': 2547,
#  'Syria': 2566,
#  'Cabo Verde': 2585,
#  'Tajikistan': 2604,
#  'Réunion': 2623,
#  'Haiti': 2642,
#  'Belize': 2661,
#  'Burkina Faso': 2680,
#  'Hong Kong': 2699,
#  'Andorra': 2718,
#  'Lesotho': 2737,
#  'Guadeloupe': 2756,
#  'Congo': 2775,
#  'Suriname': 2794,
#  'South Sudan': 2813,
#  'Guyana': 2832,
#  'Bahamas': 2851,
#  'Mali': 2870,
#  'Somalia': 2889,
#  'Aruba': 2908,
#  'Trinidad and Tobago': 2927,
#  'Togo': 2946,
#  'Martinique': 2965,
#  'Nicaragua': 2984,
#  'Equatorial Guinea': 3003,
#  'Benin': 3022,
#  'Djibouti': 3041,
#  'Iceland': 3060,
#  'CAR': 3079,
#  'Niger': 3098,
#  'Curaçao': 3117,
#  'Gambia': 3136,
#  'Gibraltar': 3155,
#  'Chad': 3174,
#  'Channel Islands': 3193,
#  'San Marino': 3212,
#  'Sierra Leone': 3231,
#  'Saint Lucia': 3250,
#  'Comoros': 3269,
#  'Mongolia': 3288,
#  'Guinea-Bissau': 3307,
#  'Barbados': 3326,
#  'Seychelles': 3345,
#  'Eritrea': 3364,
#  'Liechtenstein': 3383,
#  'Yemen': 3402,
#  'Vietnam': 3421,
#  'New Zealand': 3440,
#  'Burundi': 3459,
#  'Turks and Caicos': 3478,
#  'Sint Maarten': 3497,
#  'Liberia': 3516,
#  'Monaco': 3535,
#  'Sao Tome and Principe': 3554,
#  'Papua New Guinea': 3573,
#  'St. Vincent Grenadines': 3592,
#  'Saint Martin': 3611,
#  'Cambodia': 3630,
#  'Taiwan': 3649,
#  'Bhutan': 3668,
#  'Antigua and Barbuda': 3687,
#  'Isle of Man': 3706,
#  'Bermuda': 3725,
#  'Diamond Princess': 3744,
#  'Faeroe Islands': 3763,
#  'Mauritius': 3782,
#  'St. Barth': 3801,
#  'Caribbean Netherlands': 3820,
#  'Tanzania': 3839,
#  'Cayman Islands': 3858,
#  'Brunei ': 3877,
#  'British Virgin Islands': 3896,
#  'Grenada': 3915,
#  'Dominica': 3934,
#  'Timor-Leste': 3953,
#  'New Caledonia': 3972,
#  'Fiji': 3991,
#  'Falkland Islands': 4010,
#  'Macao': 4029,
#  'Laos': 4048,
#  'Saint Kitts and Nevis': 4067,
#  'Greenland': 4086,
#  'Vatican City': 4105,
#  'Saint Pierre Miquelon': 4124,
#  'Montserrat': 4143,
#  'Anguilla': 4162,
#  'Solomon Islands': 4181,
#  'Wallis and Futuna': 4200,
#  'Western Sahara': 4219,
#  'MS Zaandam': 4238,
#  'Marshall Islands': 4257,
#  'Samoa': 4276,
#  'Vanuatu': 4295,
#  'Micronesia': 4314,
#  'China': 4333}

# %%
pops = get_pops(soup)

# %%
# Out:
# ['Argentina',
#  2149636.0,
#  'NA',
#  52880.0,
#  'NA',
#  1945816.0,
#  'NA',
#  150940.0,
#  3467.0,
#  47268.0,
#  1163.0,
#  7720598.0,
#  169766.0,
#  45478006.0,
#  'South America']

# %%
arg = pd.DataFrame(get_country_data(soup,indexes['Argentina']), columns=['Argentina'])

cols = ['Country','Total Cases','New Cases','Total Deaths','New Deaths',
    'Total Recovered','New Recovered','Active Cases','Serious/Critical','TotalCases/1Mpop',
    'Deaths/1Mpop','Total Tests','Tests/1Mpop','Total pop','Region']

# %%
arg.index = cols

# %%
def dataframe_1_country(country):
    df = pd.DataFrame(get_country_data(soup,indexes[country]), columns=[country])
    cols = ['Country','Total Cases','New Cases','Total Deaths','New Deaths',
    'Total Recovered','New Recovered','Active Cases','Serious/Critical','TotalCases/1Mpop',
    'Deaths/1Mpop','Total Tests','Tests/1Mpop','Total pop','Region']
    df.index = cols
    return df

# %%
dataframe_1_country('Argentina')
# Out:
#                       Argentina
# Country               Argentina
# Total Cases         2.14964e+06
# New Cases                    NA
# Total Deaths              52880
# New Deaths                   NA
# Total Recovered     1.94582e+06
# New Recovered                NA
# Active Cases             150940
# Serious/Critical           3467
# TotalCases/1Mpop          47268
# Deaths/1Mpop               1163
# Total Tests          7.7206e+06
# Tests/1Mpop              169766
# Total pop            4.5478e+07
# Region            South America

# %%
arg.dtypes
# Out:
# Argentina    object
# dtype: object
